# %%
# %pip install -r req.txt
# Out:
# Requirement already satisfied: langchain in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from -r req.txt (line 1)) (1.2.10)
# Requirement already satisfied: python-dotenv in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from -r req.txt (line 2)) (1.2.1)
# Requirement already satisfied: huggingface_hub in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from -r req.txt (line 3)) (1.4.1)
# Requirement already satisfied: langchain_community in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from -r req.txt (line 4)) (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r req.txt (line 1)) (1.2.13)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r req.txt (line 1)) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r req.txt (line 1)) (2.11.9)
# Requirement already satisfied: filelock in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (0.23.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub->-r req.txt (line 3)) (4.15.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (2.13.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (0.7.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain_community->-r req.txt (line 4)) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r req.txt (line 4)) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r req.txt (line 4)) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r req.txt (line 4)) (0.9.0)
# Requirement already satisfied: anyio in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (4.10.0)
# Requirement already satisfied: certifi in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (0.16.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community->-r req.txt (line 4)) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain->-r req.txt (line 1)) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain->-r req.txt (line 1)) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain->-r req.txt (line 1)) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain->-r req.txt (line 1)) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain->-r req.txt (line 1)) (0.3.6)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain->-r req.txt (line 1)) (3.6.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->-r req.txt (line 4)) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->-r req.txt (line 4)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->-r req.txt (line 4)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r req.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r req.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r req.txt (line 1)) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community->-r req.txt (line 4)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community->-r req.txt (line 4)) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community->-r req.txt (line 4)) (3.3.1)
# Requirement already satisfied: colorama in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->-r req.txt (line 3)) (0.4.6)
# Requirement already satisfied: typer>=0.23.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from typer-slim->huggingface_hub->-r req.txt (line 3)) (0.23.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain->-r req.txt (line 1)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain->-r req.txt (line 1)) (1.12.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (8.3.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r req.txt (line 4)) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub->-r req.txt (line 3)) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sraad\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sraad\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->huggingface_hub->-r req.txt (line 3)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import langchain
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv
import os
load_dotenv(".env", override=True)
# Out:
# Token: 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

# %%
token = os.getenv("HUGGINGFACEHUB_API_TOKEN")
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct",
    task="text2text-generation",
    huggingfacehub_api_token=token,
    max_new_tokens=50
)
model = ChatHuggingFace(llm=llm)
result = model.invoke("Langchain is a framework for building what?")
print(result.content)
# Out:
# Langchain is a framework for building **conversational AI models**, specifically **transformers**, such as language models, chatbots, and voice assistants. It allows developers to create, train, and deploy AI models that can understand and generate human-like

# %%
result = model.invoke("What is Observability?")
print(result.content)
# Out:
# Observability is the ability to measure, collect, and analyze data about the internal state and behavior of a system, typically a software system, in real-time or near real-time. This allows developers, operators, and other stakeholders to understand how the system
